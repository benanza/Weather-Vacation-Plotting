# %% [markdown]
# # WeatherPy
# ----
#
# #### 3 Observable Trends:
# * The max temperature of any given place correlates relatively strongly to its latitude (moreso in the northern hemisphere).
# * The results of each hemispheres analysis do not differentiate much, aside from the max temp vs. latitude comparison.
# * Humidity is consistenly lowest for cities between 0 and 40 degrees latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import datetime in order to label plots with current date
import datetime
d = datetime.datetime.today()
date = f'{d.month}-{d.day}-{d.year}'

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output_Files/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Show the json for an example city (Chicago) so we can know how to traverse it for our list of cities
test = requests.get(f'{query_url}chicago').json()
display(test)
# Out:
# {'coord': {'lon': -87.65, 'lat': 41.85},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13n'}],
#  'base': 'stations',
#  'main': {'temp': 26.71,
#   'feels_like': 15.55,
#   'temp_min': 25,
#   'temp_max': 28.99,
#   'pressure': 1019,
#   'humidity': 63},
#  'visibility': 16093,
#  'wind': {'speed': 10.29, 'deg': 340, 'gust': 18.34},
#  'clouds': {'all': 90},
#  'dt': 1582762453,
#  'sys': {'type': 1,
#   'id': 4505,
#   'country': 'US',
#   'sunrise': 1582720270,
#   'sunset': 1582760179},
#  'timezone': -21600,
#  'id': 4887398,
#  'name': 'Chicago',
#  'cod': 200}

# %%
# set up lists to hold reponse info

cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

city_list = []

counter = 0

print('Beginning Data Retrieval')
print('-----------------------------')
# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    response_json = requests.get(query_url + city).json()
    
    try:
        
        cloudiness.append(response_json['clouds']['all'])
        country.append(response_json['sys']['country'])
        date.append(response_json['dt'])
        humidity.append(response_json['main']['humidity'])
        lat.append(response_json['coord']['lat'])
        lng.append(response_json['coord']['lon'])
        max_temp.append(response_json['main']['temp_max'])
        wind_speed.append(response_json['wind']['speed'])
        
        city_list.append(city)
        
        counter += 1
        
        print(f"Processing Record {counter} | {city}")
    
    # Handle exceptions for a character that is not available in the Star Wars API
    except:
        # Append null values
        print("City not found. Skipping...")
        pass

print('-----------------------------')
print('Data Retrieval Complete')    
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | baykalsk
# Processing Record 2 | beyneu
# Processing Record 3 | lasa
# Processing Record 4 | barrow
# Processing Record 5 | cape town
# Processing Record 6 | port alfred
# Processing Record 7 | korla
# Processing Record 8 | los llanos de aridane
# Processing Record 9 | butaritari
# Processing Record 10 | lianran
# Processing Record 11 | longyearbyen
# Processing Record 12 | ushuaia
# Processing Record 13 | dikson
# Processing Record 14 | hermanus
# Processing Record 15 | aragats
# Processing Record 16 | narsaq
# Processing Record 17 | mar del plata
# Processing Record 18 | hambantota
# Processing Record 19 | punta arenas
# Processing Record 20 | norman wells
# Processing Record 21 | aden
# Processing Record 22 | severo-kurilsk
# Processing Record 23 | thompson
# Processing Record 24 | dafeng
# Processing Record 25 | hilo
# City not found. Skipping...
# Processing Record 26 | porto novo
# Processing Record 27 | taoudenni
# Processing Record 28 | busselton
# Processing Record 29 | khatanga
# City not found. Skipping...
# Processing Record 30 | provideniya
# Processing Record 31 | atuona
# Processing Record 32 | georgetown
# Processing Record 33 | kavaratti
# Processing Record 34 | grand gaube
# Processing Record 35 | morwell
# Processing Record 36 | imeni vorovskogo
# Processing Record 37 | port hedland
# Processing Record 38 | port blair
# Processing Record 39 | okhotsk
# Processing Record 40 | elko
# Processing Record 41 | suntar
# Processing Record 42 | alamogordo
# Processing Record 43 | adrar
# Processing Record 44 | souillac
# Processing Record 45 | honningsvag
# Processing Record 46 | broome
# Processing Record 47 | san quintin
# Processing Record 48 | nikolayevsk-na-amure
# Processing Record 49 | rikitea
# Processing Record 50 | krasnyy oktyabr
# Processing Record 51 | arraial do cabo
# Processing Record 52 | cherskiy
# Processing Record 53 | jamestown
# Processing Record 54 | jalapa
# Processing Record 55 | albany
# Processing Record 56 | san rafael del sur
# Processing Record 57 | guanare
# City not found. Skipping...
# Processing Record 58 | saint george
# Processing Record 59 | oranjemund
# Processing Record 60 | sioux lookout
# Processing Record 61 | tiksi
# Processing Record 62 | russell
# Processing Record 63 | ponta do sol
# Processing Record 64 | vredendal
# Processing Record 65 | terrace
# Processing Record 66 | alyangula
# Processing Record 67 | chuy
# City not found. Skipping...
# Processing Record 68 | rawson
# Processing Record 69 | mataura
# Processing Record 70 | bredasdorp
# Processing Record 71 | burgeo
# Processing Record 72 | kodiak
# Processing Record 73 | dingle
# Processing Record 74 | san patricio
# City not found. Skipping...
# Processing Record 75 | marsa matruh
# Processing Record 76 | port hardy
# City not found. Skipping...
# Processing Record 77 | omsukchan
# Processing Record 78 | bluff
# Processing Record 79 | cascais
# City not found. Skipping...
# Processing Record 80 | bandarbeyla
# Processing Record 81 | waingapu
# Processing Record 82 | palmer
# City not found. Skipping...
# Processing Record 83 | salinas
# Processing Record 84 | aklavik
# Processing Record 85 | kapaa
# City not found. Skipping...
# Processing Record 86 | bethel
# City not found. Skipping...
# Processing Record 87 | maniitsoq
# City not found. Skipping...
# Processing Record 88 | juneau
# Processing Record 89 | yellowknife
# Processing Record 90 | new norfolk
# Processing Record 91 | san jeronimo
# City not found. Skipping...
# Processing Record 92 | sola
# Processing Record 93 | vaini
# Processing Record 94 | nikolskoye
# Processing Record 95 | tasiilaq
# Processing Record 96 | ilulissat
# Processing Record 97 | castro
# Processing Record 98 | waterfoot
# Processing Record 99 | ulaanbaatar
# City not found. Skipping...
# Processing Record 100 | nerchinskiy zavod
# Processing Record 101 | gualaquiza
# Processing Record 102 | ternate
# Processing Record 103 | semporna
# Processing Record 104 | springfield
# Processing Record 105 | hithadhoo
# Processing Record 106 | aqtobe
# Processing Record 107 | avarua
# Processing Record 108 | ahipara
# Processing Record 109 | sainte-thecle
# Processing Record 110 | natal
# Processing Record 111 | west wendover
# Processing Record 112 | baruun-urt
# Processing Record 113 | vao
# Processing Record 114 | mangan
# Processing Record 115 | east london
# Processing Record 116 | hobart
# Processing Record 117 | la ronge
# Processing Record 118 | abnub
# Processing Record 119 | alakurtti
# Processing Record 120 | salta
# Processing Record 121 | saint-philippe
# Processing Record 122 | qaanaaq
# City not found. Skipping...
# Processing Record 123 | luena
# Processing Record 124 | shimoda
# Processing Record 125 | vardo
# Processing Record 126 | puerto carreno
# Processing Record 127 | hasaki
# Processing Record 128 | petropavlovsk-kamchatskiy
# Processing Record 129 | amot
# Processing Record 130 | constitucion
# Processing Record 131 | huarmey
# Processing Record 132 | malanje
# Processing Record 133 | victoria
# Processing Record 134 | rocha
# Processing Record 135 | matara
# City not found. Skipping...
# Processing Record 136 | chara
# Processing Record 137 | dezhou
# Processing Record 138 | mehamn
# Processing Record 139 | uthal
# Processing Record 140 | moses lake
# Processing Record 141 | airai
# Processing Record 142 | sokoni
# City not found. Skipping...
# Processing Record 143 | lagoa
# Processing Record 144 | sao francisco
# Processing Record 145 | oriximina
# Processing Record 146 | kirakira
# Processing Record 147 | puerto el triunfo
# Processing Record 148 | pevek
# Processing Record 149 | haines junction
# Processing Record 150 | carnarvon
# Processing Record 151 | suda
# Processing Record 152 | siaya
# Processing Record 153 | flinders
# Processing Record 154 | salinopolis
# Processing Record 155 | fairbanks
# Processing Record 156 | sur
# Processing Record 157 | wairoa
# Processing Record 158 | kiama
# Processing Record 159 | lata
# Processing Record 160 | kabanjahe
# Processing Record 161 | hofn
# Processing Record 162 | kpandae
# Processing Record 163 | vila velha
# Processing Record 164 | taft
# Processing Record 165 | margate
# Processing Record 166 | sao filipe
# City not found. Skipping...
# Processing Record 167 | sistranda
# Processing Record 168 | cabo san lucas
# Processing Record 169 | talnakh
# Processing Record 170 | bacolod
# Processing Record 171 | kloulklubed
# Processing Record 172 | cap-chat
# Processing Record 173 | turukhansk
# Processing Record 174 | kanniyakumari
# Processing Record 175 | ribeira grande
# Processing Record 176 | prince rupert
# Processing Record 177 | kieta
# Processing Record 178 | leningradskiy
# Processing Record 179 | oranjestad
# Processing Record 180 | upernavik
# Processing Record 181 | ko samui
# Processing Record 182 | caravelas
# Processing Record 183 | agadez
# Processing Record 184 | keti bandar
# City not found. Skipping...
# Processing Record 185 | kahului
# Processing Record 186 | cayenne
# Processing Record 187 | bonavista
# Processing Record 188 | tuktoyaktuk
# Processing Record 189 | pemberton
# Processing Record 190 | fare
# Processing Record 191 | ucluelet
# Processing Record 192 | dabakala
# Processing Record 193 | lebu
# Processing Record 194 | mahebourg
# Processing Record 195 | sorong
# Processing Record 196 | luderitz
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 197 | xinxiang
# Processing Record 198 | lermontovka
# Processing Record 199 | tondano
# Processing Record 200 | mayumba
# Processing Record 201 | chicama
# Processing Record 202 | port elizabeth
# Processing Record 203 | quesnel
# Processing Record 204 | cidreira
# Processing Record 205 | vestmannaeyjar
# Processing Record 206 | rabo de peixe
# City not found. Skipping...
# Processing Record 207 | hervey bay
# Processing Record 208 | cristobal obregon
# Processing Record 209 | nanortalik
# City not found. Skipping...
# Processing Record 210 | pisco
# Processing Record 211 | zlobin
# Processing Record 212 | high level
# Processing Record 213 | camacha
# Processing Record 214 | north bend
# Processing Record 215 | ishikari
# Processing Record 216 | kaitangata
# Processing Record 217 | balaguer
# Processing Record 218 | dunda
# Processing Record 219 | silver city
# Processing Record 220 | tuatapere
# Processing Record 221 | clyde river
# Processing Record 222 | teguldet
# Processing Record 223 | yulara
# Processing Record 224 | calabozo
# Processing Record 225 | ascension
# Processing Record 226 | coahuayana
# Processing Record 227 | sisimiut
# Processing Record 228 | mount isa
# Processing Record 229 | camocim
# Processing Record 230 | outlook
# Processing Record 231 | quatre cocos
# Processing Record 232 | kalaleh
# Processing Record 233 | kabansk
# Processing Record 234 | asau
# Processing Record 235 | hovd
# Processing Record 236 | pakhni
# Processing Record 237 | kulhudhuffushi
# Processing Record 238 | lufilufi
# City not found. Skipping...
# Processing Record 239 | saskylakh
# Processing Record 240 | tome
# Processing Record 241 | shakhtinsk
# Processing Record 242 | san clemente
# Processing Record 243 | keuruu
# Processing Record 244 | prince albert
# Processing Record 245 | kruisfontein
# Processing Record 246 | ygatimi
# Processing Record 247 | geraldton
# Processing Record 248 | puerto ayora
# Processing Record 249 | muros
# Processing Record 250 | comodoro rivadavia
# Processing Record 251 | marsh harbour
# Processing Record 252 | badou
# Processing Record 253 | malyye derbety
# Processing Record 254 | valdivia
# Processing Record 255 | khartoum
# Processing Record 256 | tamworth
# City not found. Skipping...
# Processing Record 257 | babu
# Processing Record 258 | canico
# Processing Record 259 | maldonado
# Processing Record 260 | kalvarija
# Processing Record 261 | whitehorse
# Processing Record 262 | tual
# Processing Record 263 | fomboni
# Processing Record 264 | meadow lake
# Processing Record 265 | tezu
# Processing Record 266 | mombetsu
# City not found. Skipping...
# Processing Record 267 | carlyle
# Processing Record 268 | awbari
# City not found. Skipping...
# Processing Record 269 | atar
# Processing Record 270 | marawi
# Processing Record 271 | kristiinankaupunki
# Processing Record 272 | lompoc
# Processing Record 273 | havoysund
# Processing Record 274 | saint-pierre
# Processing Record 275 | kerman
# Processing Record 276 | khuzhir
# Processing Record 277 | maraa
# Processing Record 278 | davila
# Processing Record 279 | yandyki
# Processing Record 280 | dunedin
# Processing Record 281 | lucea
# Processing Record 282 | codrington
# Processing Record 283 | faya
# Processing Record 284 | port macquarie
# Processing Record 285 | kargasok
# Processing Record 286 | presidencia roque saenz pena
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 287 | dudinka
# City not found. Skipping...
# Processing Record 288 | dzilam gonzalez
# Processing Record 289 | kavieng
# Processing Record 290 | aitape
# Processing Record 291 | san policarpo
# Processing Record 292 | palana
# Processing Record 293 | vostok
# Processing Record 294 | kresttsy
# Processing Record 295 | klaksvik
# Processing Record 296 | juru
# Processing Record 297 | westerland
# Processing Record 298 | cap malheureux
# Processing Record 299 | waipawa
# City not found. Skipping...
# Processing Record 300 | harper
# Processing Record 301 | chernyshevskiy
# Processing Record 302 | rodeo
# Processing Record 303 | mount gambier
# Processing Record 304 | niamey
# Processing Record 305 | jalu
# Processing Record 306 | sri aman
# Processing Record 307 | necochea
# Processing Record 308 | evensk
# Processing Record 309 | osinki
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 310 | linhares
# Processing Record 311 | iqaluit
# Processing Record 312 | axim
# City not found. Skipping...
# Processing Record 313 | padang
# Processing Record 314 | chumikan
# Processing Record 315 | gasa
# Processing Record 316 | daru
# Processing Record 317 | kasempa
# Processing Record 318 | vanimo
# Processing Record 319 | srednekolymsk
# Processing Record 320 | iquitos
# Processing Record 321 | villazon
# Processing Record 322 | auki
# Processing Record 323 | bidor
# Processing Record 324 | wanaka
# City not found. Skipping...
# Processing Record 325 | energetik
# Processing Record 326 | anloga
# Processing Record 327 | kununurra
# Processing Record 328 | piacabucu
# Processing Record 329 | idlib
# Processing Record 330 | banepa
# Processing Record 331 | kupang
# Processing Record 332 | mlonggo
# Processing Record 333 | awjilah
# Processing Record 334 | maine-soroa
# Processing Record 335 | kokkola
# Processing Record 336 | bokaa
# Processing Record 337 | buala
# Processing Record 338 | namatanai
# Processing Record 339 | kidal
# Processing Record 340 | doha
# Processing Record 341 | beaverlodge
# Processing Record 342 | esperance
# Processing Record 343 | antibes
# Processing Record 344 | belaya gora
# Processing Record 345 | samarai
# Processing Record 346 | bartica
# Processing Record 347 | salalah
# Processing Record 348 | suoyarvi
# Processing Record 349 | novocheremshansk
# Processing Record 350 | conceicao da barra
# Processing Record 351 | shingu
# Processing Record 352 | zarand
# Processing Record 353 | kortkeros
# Processing Record 354 | lobatse
# Processing Record 355 | jiamusi
# Processing Record 356 | yumen
# Processing Record 357 | seddon
# Processing Record 358 | cavan
# Processing Record 359 | mecca
# Processing Record 360 | soe
# Processing Record 361 | saint-paul
# Processing Record 362 | polunochnoye
# Processing Record 363 | yamethin
# Processing Record 364 | simao
# Processing Record 365 | kondinskoye
# Processing Record 366 | san cristobal
# City not found. Skipping...
# Processing Record 367 | rio cuarto
# Processing Record 368 | sadove
# Processing Record 369 | ostrovnoy
# Processing Record 370 | roblin
# Processing Record 371 | boulsa
# Processing Record 372 | pavilosta
# Processing Record 373 | storforshei
# Processing Record 374 | zhigansk
# Processing Record 375 | general pico
# Processing Record 376 | alofi
# Processing Record 377 | biak
# Processing Record 378 | takoradi
# Processing Record 379 | hualmay
# Processing Record 380 | yangambi
# Processing Record 381 | diamantino
# Processing Record 382 | kouango
# Processing Record 383 | cape canaveral
# Processing Record 384 | nabire
# Processing Record 385 | buraydah
# Processing Record 386 | khorixas
# Processing Record 387 | xingyi
# City not found. Skipping...
# Processing Record 388 | magadi
# Processing Record 389 | ladispoli
# Processing Record 390 | wattegama
# Processing Record 391 | nome
# City not found. Skipping...
# Processing Record 392 | luangwa
# City not found. Skipping...
# Processing Record 393 | faanui
# Processing Record 394 | talas
# Processing Record 395 | chokurdakh
# Processing Record 396 | bilma
# Processing Record 397 | serro
# Processing Record 398 | ho chi minh city
# Processing Record 399 | vilyuysk
# Processing Record 400 | torbay
# Processing Record 401 | rio grande city
# Processing Record 402 | coihaique
# Processing Record 403 | beidao
# Processing Record 404 | bubaque
# Processing Record 405 | rosamorada
# City not found. Skipping...
# Processing Record 406 | surt
# City not found. Skipping...
# Processing Record 407 | svetlyy
# Processing Record 408 | birao
# Processing Record 409 | bambous virieux
# Processing Record 410 | bossier city
# Processing Record 411 | tombouctou
# City not found. Skipping...
# Processing Record 412 | santiago del estero
# Processing Record 413 | guerrero negro
# Processing Record 414 | villa constitucion
# Processing Record 415 | pitsunda
# Processing Record 416 | bengkulu
# Processing Record 417 | lamu
# Processing Record 418 | gribanovskiy
# Processing Record 419 | arlit
# Processing Record 420 | rtishchevo
# Processing Record 421 | shahrud
# Processing Record 422 | vila
# Processing Record 423 | sumenep
# City not found. Skipping...
# Processing Record 424 | pitiquito
# Processing Record 425 | xining
# Processing Record 426 | saint anthony
# Processing Record 427 | singaraja
# Processing Record 428 | maltahohe
# Processing Record 429 | sao felix do xingu
# Processing Record 430 | acarau
# Processing Record 431 | rio grande
# Processing Record 432 | trinidad
# Processing Record 433 | nador
# Processing Record 434 | nantucket
# Processing Record 435 | dakoro
# Processing Record 436 | altay
# Processing Record 437 | fortuna
# Processing Record 438 | chadiza
# Processing Record 439 | monteiro
# Processing Record 440 | castelnau-le-lez
# Processing Record 441 | palmas
# Processing Record 442 | sao joao da barra
# Processing Record 443 | hindaun
# Processing Record 444 | neuquen
# Processing Record 445 | pacifica
# City not found. Skipping...
# Processing Record 446 | saint-georges
# Processing Record 447 | trairi
# Processing Record 448 | katsuura
# Processing Record 449 | zhangjiakou
# Processing Record 450 | vilhena
# Processing Record 451 | udachnyy
# Processing Record 452 | san pedro
# Processing Record 453 | nhulunbuy
# Processing Record 454 | roald
# Processing Record 455 | tukrah
# Processing Record 456 | praia
# Processing Record 457 | alice springs
# City not found. Skipping...
# Processing Record 458 | lac du bonnet
# Processing Record 459 | balkanabat
# Processing Record 460 | nanticoke
# Processing Record 461 | dalby
# Processing Record 462 | zhezkazgan
# Processing Record 463 | dwarka
# Processing Record 464 | hushitai
# Processing Record 465 | orocue
# Processing Record 466 | karasjok
# Processing Record 467 | goderich
# Processing Record 468 | ozernovskiy
# Processing Record 469 | voh
# City not found. Skipping...
# Processing Record 470 | tubuala
# Processing Record 471 | berlevag
# Processing Record 472 | winsford
# Processing Record 473 | amga
# Processing Record 474 | port moresby
# Processing Record 475 | ixtapa
# Processing Record 476 | novotroitsk
# Processing Record 477 | skibbereen
# Processing Record 478 | kefamenanu
# Processing Record 479 | rundu
# City not found. Skipping...
# Processing Record 480 | anadyr
# Processing Record 481 | ngunguru
# Processing Record 482 | luganville
# Processing Record 483 | la paz
# City not found. Skipping...
# Processing Record 484 | invercargill
# Processing Record 485 | rio gallegos
# Processing Record 486 | belmonte
# Processing Record 487 | broadstairs
# Processing Record 488 | khovu-aksy
# Processing Record 489 | khilok
# Processing Record 490 | beringovskiy
# Processing Record 491 | preobrazheniye
# Processing Record 492 | san fernando
# Processing Record 493 | diego de almagro
# Processing Record 494 | aquiraz
# Processing Record 495 | yaan
# Processing Record 496 | atbasar
# Processing Record 497 | berbera
# Processing Record 498 | komsomolskiy
# Processing Record 499 | sinnamary
# Processing Record 500 | palasa
# Processing Record 501 | gizo
# City not found. Skipping...
# Processing Record 502 | pajapan
# City not found. Skipping...
# Processing Record 503 | hoquiam
# Processing Record 504 | byron bay
# City not found. Skipping...
# Processing Record 505 | pombia
# Processing Record 506 | soyo
# Processing Record 507 | hay river
# Processing Record 508 | ojinaga
# Processing Record 509 | gat
# Processing Record 510 | pietermaritzburg
# Processing Record 511 | avera
# Processing Record 512 | tekeli
# Processing Record 513 | san matias
# Processing Record 514 | saint-germain-de-grantham
# City not found. Skipping...
# Processing Record 515 | floro
# Processing Record 516 | pimentel
# Processing Record 517 | chinsali
# Processing Record 518 | kemin
# Processing Record 519 | gillette
# Processing Record 520 | oksfjord
# Processing Record 521 | sorochinsk
# Processing Record 522 | milkovo
# Processing Record 523 | parrita
# Processing Record 524 | tigil
# Processing Record 525 | ancud
# Processing Record 526 | stepnyak
# Processing Record 527 | jibuti
# Processing Record 528 | boende
# City not found. Skipping...
# Processing Record 529 | nandaime
# Processing Record 530 | ugoofaaru
# Processing Record 531 | walvis bay
# Processing Record 532 | vila franca do campo
# Processing Record 533 | surin
# Processing Record 534 | mastung
# Processing Record 535 | hobyo
# Processing Record 536 | guatire
# Processing Record 537 | fort nelson
# Processing Record 538 | kodinar
# Processing Record 539 | isangel
# Processing Record 540 | sale
# Processing Record 541 | poya
# Processing Record 542 | pasighat
# Processing Record 543 | laguna
# Processing Record 544 | volchikha
# Processing Record 545 | puerto leguizamo
# Processing Record 546 | broken hill
# Processing Record 547 | pierre
# Processing Record 548 | olinda
# Processing Record 549 | lubao
# Processing Record 550 | namibe
# Processing Record 551 | khandbari
# Processing Record 552 | lakes entrance
# Processing Record 553 | rawlins
# Processing Record 554 | abu samrah
# Processing Record 555 | shirokiy
# Processing Record 556 | bulaevo
# Processing Record 557 | praia da vitoria
# Processing Record 558 | tecoanapa
# Processing Record 559 | jeremoabo
# Processing Record 560 | mattru
# Processing Record 561 | chardara
# Processing Record 562 | ereymentau
# Processing Record 563 | slave lake
# Processing Record 564 | port lincoln
# Processing Record 565 | sitka
# Processing Record 566 | ovada
# Processing Record 567 | yaring
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create DataFrame

city_df = pd.DataFrame({
    'City': city_list,
    'Cloudiness': cloudiness,
    'Country': country,
    'Date': date,
    'Humidity': humidity,
    'Lat': lat,
    'Lng': lng,
    'Max Temp': max_temp,
    'Wind Speed': wind_speed
})

display(city_df)

# Export Dataframe into a .csv
city_df.to_csv(output_data_file)
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        baykalsk          94      RU  1582762542        82  51.51  104.15
# 1          beyneu           0      KZ  1582762542        56  45.32   55.20
# 2            lasa          90      IT  1582762542        92  46.62   10.70
# 3          barrow           1      US  1582762337        74  71.29 -156.79
# 4       cape town          20      ZA  1582762319        82 -33.93   18.42
# ..            ...         ...     ...         ...       ...    ...     ...
# 562    slave lake          90      CA  1582762622        60  55.28 -114.77
# 563  port lincoln           0      AU  1582762622        54 -34.73  135.87
# 564         sitka          90      US  1582762622        75  57.05 -135.33
# 565         ovada           0      IT  1582762622        28  44.64    8.65
# 566        yaring          35      TH  1582762622        79   6.87  101.37
#
#      Max Temp  Wind Speed
# 0        5.40        6.44
# 1       33.04        6.69
# 2       32.00        1.12
# 3      -25.60        4.70
# 4       66.99       19.46
# ..        ...         ...
# 562     39.20       10.29
# 563     63.25        9.08
# 564     42.80       12.75
# 565     46.40        3.36
# 566     80.38       21.25
#
# [567 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'

x = city_df['Lat']
y = city_df['Max Temp']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='YlOrRd', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Max Temperature ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('Output_Files/Lat_v_Temp.png')

plt.show()

# %% [markdown]
# #### Notes on Latitude vs. Max Temp Plot
# * The code uses the matplotlib module to give us a scatter plot comparing the max temperatures across latitudes
#   using the data from our created DataFrame.
# * The results of the scatter plot seem to show a noticeable correlation between
#   latitude and temperature: the closer the latitude is to zero, the hotter the temperature.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Humidity'

x = city_df['Lat']
y = city_df['Humidity']

# Set color to the value of 'Humidity' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='YlGnBu', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Humidity ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('Output_Files/Lat_v_Humidity.png')

plt.show()

# %% [markdown]
# #### Notes on Latitude vs. Humidity Plot
# * The code uses the matplotlib module to give us a scatter plot comparing the humidity percentages across latitudes
#   using the data from our created DataFrame.
# * The results of the scatter plot show less of a correlation than latitude vs. temperature, though perhaps one could observe that overall humidity drops between 0 and 40 degrees latitude.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Cloudiness'

x = city_df['Lat']
y = city_df['Cloudiness']

# Set color to the value of 'Cloudiness' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Blues', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Cloudiness ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('Output_Files/Lat_v_Cloudiness.png')

plt.show()

# %% [markdown]
# #### Notes on Latitude vs. Cloudiness Plot
# * The code uses the matplotlib module to give us a scatter plot comparing the cloudiness percentage across latitudes
#   using the data from our created DataFrame.
# * The results of the scatter plot show not so much a correlation between latitude and cloudiness,
#   but rather demonstrate the consistency of cloudiness percentage at certain values,
#   notably 0%, 20%, 40%, 75%, and 100%.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Wind Speed'

x = city_df['Lat']
y = city_df['Wind Speed']

# Set color to the value of 'Wind Speed' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='YlGn', edgecolor='gray')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs. Wind Speed ({date})')
plt.grid()

# Save plot as png file in output folder
plt.savefig('Output_Files/Lat_v_WindSpeed.png')

plt.show()

# %% [markdown]
# #### Notes on Latitude vs. Wind Speed Plot
# * The code uses the matplotlib module to give us a scatter plot comparing the wind speed across latitudes
#   using the data from our created DataFrame.
# * The results of the scatter plot seem to show little to no correlation between
#   latitude and wind speed.
# * We can note that it seems rare for wind speeds to rise above 20 mph.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def regressplot(x, y):
    
    # Calculate the correlation coefficient between mouse weight and average tumor volume
    correlation = st.pearsonr(x,y)

    # Print the answer to above calculation, but squared
    print(f"""The r-squared value is {round((correlation[0]**2),2)}""")

    # Calculate linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot linear regression on top of scatter plot
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = city_df.loc[city_df['Lat'] >= 0]
south_df = city_df.loc[city_df['Lat'] < 0]
north_df.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  baykalsk          94      RU  1582762542        82  51.51  104.15
# 1    beyneu           0      KZ  1582762542        56  45.32   55.20
# 2      lasa          90      IT  1582762542        92  46.62   10.70
# 3    barrow           1      US  1582762337        74  71.29 -156.79
# 6     korla          58      CN  1582762542        86  41.76   86.15
#
#    Max Temp  Wind Speed
# 0      5.40        6.44
# 1     33.04        6.69
# 2     32.00        1.12
# 3    -25.60        4.70
# 6     27.00        7.00

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters (be sure to run previous cells first
# in order to call the north and south dataframes)
line_eq = regressplot(x = north_df['Lat'], y = north_df['Max Temp'])

# Annotate linear regression
plt.annotate(line_eq,(10,-10),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig('Output_Files/North_Temp.png')

plt.show()
# Out:
# The r-squared value is 0.8

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = south_df['Lat'], y = south_df['Max Temp'])

# Annotate linear regression
plt.annotate(line_eq,(-30,52),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig('Output_Files/South_Temp.png')

plt.show()
# Out:
# The r-squared value is 0.31

# %% [markdown]
# #### Analysis of Latitude vs. Max Temp:
# * The correlation between these values in the Northern Hemisphere is relatively high.
# * The correlation between these values in the Southern Hemisphere is almost non-existent.
#     Overall, there is a slight increase in max temp as latitude approaches 0, but with an
#     r-squared value of only 0.31, it clearly does not change as consistenly as the Northern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = north_df['Lat'], y = north_df['Humidity'])

# Annotate linear regression
plt.annotate(line_eq,(45,17),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig('Output_Files/North_Humidity.png')

plt.show()
# Out:
# The r-squared value is 0.08

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = south_df['Lat'], y = south_df['Humidity'])

# Annotate linear regression
plt.annotate(line_eq,(-25,40),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig('Output_Files/South_Humidity.png')

plt.show()
# Out:
# The r-squared value is 0.17

# %% [markdown]
# #### Analysis of Latitude vs. Humidity:
# * While the correlation between these values is a bit higher for the southern hemisphere,
#     the correlation in both hemispheres is not high enough to demonstrate any real-world correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = north_df['Lat'], y = north_df['Cloudiness'])

# Annotate linear regression
plt.annotate(line_eq,(32,26),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig('Output_Files/North_Cloudiness.png')

plt.show()
# Out:
# The r-squared value is 0.08

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = south_df['Lat'], y = south_df['Cloudiness'])

# Annotate linear regression
plt.annotate(line_eq,(-50,27),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig('Output_Files/South_Cloudiness.png')

plt.show()
# Out:
# The r-squared value is 0.07

# %% [markdown]
# #### Analysis of Latitude vs. Cloudiness:
# * The correlation between these values in both hemispheres is almost identical, and not high enough to demonstrate any real world correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = north_df['Lat'], y = north_df['Wind Speed'])

# Annotate linear regression
plt.annotate(line_eq,(10,35),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig('Output_Files/North_WindSpeed.png')

plt.show()
# Out:
# The r-squared value is 0.01

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call Regression Function and pass appropriate parameters
line_eq = regressplot(x = south_df['Lat'], y = south_df['Wind Speed'])

# Annotate linear regression
plt.annotate(line_eq,(-25,27),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig('Output_Files/South_WindSpeed.png')

plt.show()
# Out:
# The r-squared value is 0.2

# %% [markdown]
# #### Analysis of Latitude vs. Wind Speed:
# * The correlation between these values is significantly higher in the southern hemisphere: wind speed does seem to decrease as we approach the equator. As for the norther hemisphere, there is virtually no correlation.
